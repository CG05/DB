# %% [markdown]
# # 1\. 함수는?
#
# - 일반적으로 함수도 데이터 타입의 하나다.
# - 파이썬의 모든 것은 데이터 형태로 사용할 수 있다.
# - 다음과 같은 기능을 하는 함수를 만들어 본다.
#
# - 제곱하는 함수
#   - 입력 : [  1,  2,  3] → 리턴 : [ 1, 4, 9]
#
# - 절대값을 구하는 함수
#   - 입력 : [ -1,  2, -3] → 리턴 : [ 1, 2, 3]
#
# - 둘다 집합 데이터를 입력 받아서 같은 위치의 원소를 연산하여 결과값을 만드는 함수다.

# %% [markdown]
# - 함수도 데이터 타입이다.

# %% [markdown]
# - 함수를 매개변수 값으로 반환할 수 있다.

# %% [markdown]
# # 2\. Lambda (람다)
# - 이름이 없는 익명의 inline 함수 정의한다.
# ```
# 구문
# lambda [parameters] : expression
# ```

# %% [markdown]
# - 간단한 동작의 함수들은 lambda 로 만들어서 함수 호출 시 필요할 때 전달해 주는 형태로 활용한다.

# %% [markdown]
# - lambda 는 여러 줄을 사용할 수 없다.

# %% [markdown]
# - map(), filter(), reduce() 에서 lambda 활용을 많이 한다.
# - map : n → n (n개의 입력을 받아 어떤 동작을 적용하여 n 개의 결과값을 생성한다)
# - filter : n → n' (n개의 입력을 받아 어떤 동작을 적용하여 n 보다 적거나 같은 수의 결과값을 생성한다.)
# - reduce : n → 1 (n개의 입력을 받아 어떤 동작을 적용하여 1개의 결과값을 생성한다.)

# %%
# x = '2'
# return int(x) if x.isdigit() else x
# if x.isdigit():
#     return int(x)
x = '2'
if x.isdigit():
    print(int(x))
else:
    print(x)

# %% [markdown]
# # 3\. Map 함수
# - map 함수는 n개의 입력을 받으면 n개의 결과값을 반환한다.
# - 집합데이터에 ~~한 동작/연산을 수행/적용하는 함수를 세트로 주어 일괄로 처리할 수 있다.
# - 파이썬에는 이와 같은 일을 처리하는 함수가 있는데 바로 map 함수이다.
# ```
# 구문
# map(함수, iterable 데이터)
# ```
# - map 함수의 데이터는 iterable 해야 하고 map 함수의 리턴값은 map 객체이고 이 또한 iterable 하다.
# - iterable 자료형 : list, set, dict, tuple, str 등이 있다.

# %% [markdown]
# # 문제
# - 주어진 리스트의 멤버들을 제곱해서 음수값으로 추력
# - lambda와 map 을 이용해서 풀어보세요
# ```
# [ 3, 2, -4] → [-9, -4, -16]
# ```

# %%
li = [3,2,-4]
square = map((lambda x : x**2), li)
print(list(square))
# Out:
# [9, 4, 16]

# %% [markdown]
# # 문제
# - csv 파일 형태의 데이터를 아래와 같은 형태로 만들어 보세요.
# ```python
# data = """height,weight,label
# 140,45,normal
# 145,72,fat
# 150,61,fat
# 137,56,fat
# 192,48,thin
# 175,77,fat"""
# <결과값>
# [[140.0, 45.0, 'normal'],
# [145.0, 72.0, 'fat'],
# [150.0, 61.0, 'fat'],
# [137.0, 56.0, 'fat'],
# [192.0, 48.0, 'thin'],
# [175.0, 77.0, 'fat']]
# ```

# %% [markdown]
# - 과정 Hint
#   - line 별로 나누기
#   - 나누어진 line 은 ',' 로 나누기
#   - 각 데이터의 숫자는 float 로, 문자는 그대로 저장

# %%
data = """height,weight,label
140,45,normal
145,72,fat
150,61,fat
137,56,fat
192,48,thin
175,77,fat"""
lines = data.split("\n")
info = list(map(lambda line : line.split(','), lines[1:]))
info = list(map(lambda line : list(map(lambda x : float(x) if x.isdigit() else x, line)), info))
info
# Out:
# [[140.0, 45.0, 'normal'],
#  [145.0, 72.0, 'fat'],
#  [150.0, 61.0, 'fat'],
#  [137.0, 56.0, 'fat'],
#  [192.0, 48.0, 'thin'],
#  [175.0, 77.0, 'fat']]

# %%
data2 = data.split('\n')[1:]
lst = []
lst2 = []

for i in data2: # map(lambda i : {} , data2)
    for j in range(3): # map(lambda j : {} , i)
        if i.split(',')[j].isdigit(): 
            lst.append(float(i.split(',')[j])) 
            lst.append(i.split(',')[j])
        # float(i.split(',')[j]) if i.split(',')[j].isdigit() else i.split(',')[j]
    lst2.append(lst)
    lst = []

# -> map(lambda i : map(lambda j : float(j) if j.isdigit() else j, i.split(',')), data2)
list(map(lambda i : list(map(lambda j : float(j) if j.isdigit() else j, i.split(','))), data2))
# Out:
# [[140.0, 45.0, 'normal'],
#  [145.0, 72.0, 'fat'],
#  [150.0, 61.0, 'fat'],
#  [137.0, 56.0, 'fat'],
#  [192.0, 48.0, 'thin'],
#  [175.0, 77.0, 'fat']]

# %% [markdown]
# - if와 for문을 사용한다면

# %% [markdown]
# # 4\. filter 함수
# - n 개를 데이터는 filter 에 인자로 사용되는 함수에서 처리되는 과정에서 각각의 요소에 대해 참과 거짓 값을 반환한다.
# - 참을 반환하면 그 요소는 남게 되고, 거짓을 반환하면 그 요소는 제거된다.
# - filter 함수 결과는 filter 객체로 반환 되며, 이 객체 또한 iterable 하다.
# ```
# 구문
# filter(function, iterable)
# ```

# %% [markdown]
# ```
# 입력 : [ 3. 7, 9 ]
#          ↓ ↓ ↓
# 적용 :  multiple3
#          ↓ ↓ ↓
# 반환 :   T  F  T
#          ↓   ↓
# 최종 : [ 3,    9 ]
# ```

# %%
li = [3, 7, 9]
print(list(filter(lambda x : x % 3 == 0, li)))
# Out:
# [3, 9]

# %% [markdown]
# # 5\. reduce 함수
# - 함수를 사용해서 iterable을 집계연산을 통해 하나의 값을 반환한다.
# - initializer 는 주어지면 첫번째 인자로 추가된다.
# ```
# 구문
# functools.reduce(function, iterable[, initializer])
# ```

# %% [markdown]
# ```
# [ 1 , 2 , 3 , 4 , 5]
# add(1,2)
#     add)3,3)
#        add)6, 4)
#           add(10, 5)
# ```

# %% [markdown]
# ## initializer (초기값)

# %% [markdown]
# # 문제
# - reduce와 lambda 를 사용하여 최댓값을 찾아보세요.
# ```
# dataset = [1,4,3,5,2]
# ```

# %%
from functools import reduce
dataset = [1,4,3,5,2]
reduce(lambda x, y: x if x>y else y, dataset)
# Out:
# 5

# %% [markdown]
# # 문제
# - 각각의 아이템 수를 구해보세요
# ```
# dataset = ['dog', 'dog', 'dog', 'cat', 'cat', 'bird']
# ```

# %%
dataset = ['dog', 'dog', 'dog', 'cat', 'cat', 'bird']

# print(dict(l))
list(map(lambda x : dataset.count(x), set(dataset)))
dict(reduce(lambda d, x : (lambda x: d[x] = dataset.count(x)) or d, set(dataset), {}))
# Out:
#   Cell In[84], line 5
#     dict(reduce(lambda d, x : (d[x] = dataset.count(x)) or d, set(dataset), {}))
#                                ^
# SyntaxError: cannot assign to subscript here. Maybe you meant '==' instead of '='?

# %% [markdown]
# - map, filter 함수도 reduce 로 가능하다.
