# %% [markdown]
# # column 선택하기
#   - 기본적으로 [ ]는 column을 추출
#   - 컬럼 인덱스일 경우 인덱스의 리스트 사용 가능
#     - 리스트를 전달할 경우 결과는 Dataframe
#     - 하나의 컬럼명을 전달할 경우 결과는 Series

# %%
import pandas as pd
import numpy as np

# %%
filepath = 'data/titanic.csv'
df = pd.read_csv(filepath)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 하나의 컬럼 선택하기

# %% [markdown]
# > df[0] 으로 가져오기를 하면 index 가 아닌 columns 를 가져오기를 한다.

# %%
# 특정 컬럼을 가지고 오려면...
df['Pclass'] # 결과값은 Series 로 반환
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
# 다른 방법은
df.Pclass
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %% [markdown]
# ## 복수의 컬럼 선택하기
# - list 형태로 컬럼을 넣으면

# %%
# list 로 컬럼을 가져오면 ...
df[['Pclass']] # 결과값은 DataFrame으로 반환
# Out:
#      Pclass
# 0         3
# 1         1
# 2         3
# 3         1
# 4         3
# ..      ...
# 886       2
# 887       1
# 888       3
# 889       1
# 890       3
#
# [891 rows x 1 columns]

# %%
# 기존 컬럼의 순서가 아닌 명시된 순서대로 출력된다.
df[['Pclass', 'Age', 'Name']]
# Out:
#      Pclass   Age                                               Name
# 0         3  22.0                            Braund, Mr. Owen Harris
# 1         1  38.0  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         3  26.0                             Heikkinen, Miss. Laina
# 3         1  35.0       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         3  35.0                           Allen, Mr. William Henry
# ..      ...   ...                                                ...
# 886       2  27.0                              Montvila, Rev. Juozas
# 887       1  19.0                       Graham, Miss. Margaret Edith
# 888       3   NaN           Johnston, Miss. Catherine Helen "Carrie"
# 889       1  26.0                              Behr, Mr. Karl Howell
# 890       3  32.0                                Dooley, Mr. Patrick
#
# [891 rows x 3 columns]

# %%
# 순서가 무관하고 동일한 컬럼을 여러번 호출할 수 있다.
df[['Name', 'Age', 'Survived', 'Survived']]
# Out:
#                                                   Name   Age  Survived  \
# 0                              Braund, Mr. Owen Harris  22.0         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0         1
# 2                               Heikkinen, Miss. Laina  26.0         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0         1
# 4                             Allen, Mr. William Henry  35.0         0
# ..                                                 ...   ...       ...
# 886                              Montvila, Rev. Juozas  27.0         0
# 887                       Graham, Miss. Margaret Edith  19.0         1
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN         0
# 889                              Behr, Mr. Karl Howell  26.0         1
# 890                                Dooley, Mr. Patrick  32.0         0
#
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 886         0
# 887         1
# 888         0
# 889         1
# 890         0
#
# [891 rows x 4 columns]

# %% [markdown]
# ---
# # Row 선택하기

# %% [markdown]
# ## DataFrame slicing
#   - dataframe의 경우 기본적으로 [] 연산는 **column 선택**에 사용  `(인덱싱 용이 아니다!!)`
#   - 하지만, slicing은 row 레벨로 지원

# %%
# slicing 은 row level 로 동작한다.
df[:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
# 6      0             17463  51.8625   E46        S
# 7      1            349909  21.0750   NaN        S
# 8      2            347742  11.1333   NaN        S
# 9      0            237736  30.0708   NaN        C

# %%
df[7:10]
# Out:
#    PassengerId  Survived  Pclass  \
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 7                     Palsson, Master. Gosta Leonard    male   2.0      3
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch  Ticket     Fare Cabin Embarked
# 7      1  349909  21.0750   NaN        S
# 8      2  347742  11.1333   NaN        S
# 9      0  237736  30.0708   NaN        C

# %%
df[-5:]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df[::10]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 10            11         1       3
# 20            21         0       2
# 30            31         0       1
# 40            41         0       3
# ..           ...       ...     ...
# 850          851         0       3
# 860          861         0       3
# 870          871         0       3
# 880          881         1       2
# 890          891         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 0                           Braund, Mr. Owen Harris    male  22.0      1
# 10                  Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 20                             Fynney, Mr. Joseph J    male  35.0      0
# 30                         Uruchurtu, Don. Manuel E    male  40.0      0
# 40   Ahlin, Mrs. Johan (Johanna Persdotter Larsson)  female  40.0      1
# ..                                              ...     ...   ...    ...
# 850         Andersson, Master. Sigvard Harald Elias    male   4.0      4
# 860                         Hansen, Mr. Claus Peter    male  41.0      2
# 870                               Balkic, Mr. Cerin    male  26.0      0
# 880    Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 890                             Dooley, Mr. Patrick    male  32.0      0
#
#      Parch     Ticket     Fare Cabin Embarked
# 0        0  A/5 21171   7.2500   NaN        S
# 10       1    PP 9549  16.7000    G6        S
# 20       0     239865  26.0000   NaN        S
# 30       0   PC 17601  27.7208   NaN        C
# 40       0       7546   9.4750   NaN        S
# ..     ...        ...      ...   ...      ...
# 850      2     347082  31.2750   NaN        S
# 860      0     350026  14.1083   NaN        S
# 870      0     349248   7.8958   NaN        S
# 880      1     230433  26.0000   NaN        S
# 890      0     370376   7.7500   NaN        Q
#
# [90 rows x 12 columns]

# %%
df[::-1]
# Out:
#      PassengerId  Survived  Pclass  \
# 890          891         0       3
# 889          890         1       1
# 888          889         0       3
# 887          888         1       1
# 886          887         0       2
# ..           ...       ...     ...
# 4              5         0       3
# 3              4         1       1
# 2              3         1       3
# 1              2         1       1
# 0              1         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 890                                Dooley, Mr. Patrick    male  32.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# ..                                                 ...     ...   ...    ...
# 4                             Allen, Mr. William Henry    male  35.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 0                              Braund, Mr. Owen Harris    male  22.0      1
#
#      Parch            Ticket     Fare Cabin Embarked
# 890      0            370376   7.7500   NaN        Q
# 889      0            111369  30.0000  C148        C
# 888      2        W./C. 6607  23.4500   NaN        S
# 887      0            112053  30.0000   B42        S
# 886      0            211536  13.0000   NaN        S
# ..     ...               ...      ...   ...      ...
# 4        0            373450   8.0500   NaN        S
# 3        0            113803  53.1000  C123        S
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 0        0         A/5 21171   7.2500   NaN        S
#
# [891 rows x 12 columns]

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df['Survived'][:10]
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# 5    0
# 6    0
# 7    0
# 8    1
# 9    1
# Name: Survived, dtype: int64

# %% [markdown]
# > [] 는 기본적으로 column 을 지정하는데 슬라이싱 할 경우 전체 컬럼의 크기를 가져와하기 때문에 row 를 선택한것 처럼 보이는 것이다.
# > 컬럼을 따로 지정 하지 않으면 전체 컬럼에서 값을 가져오기 때문에 row 를 가져온 것처럼 보인다.

# %%
df[['Survived', 'Pclass', 'Age']][:10]
# Out:
#    Survived  Pclass   Age
# 0         0       3  22.0
# 1         1       1  38.0
# 2         1       3  26.0
# 3         1       1  35.0
# 4         0       3  35.0
# 5         0       3   NaN
# 6         0       1  54.0
# 7         0       3   2.0
# 8         1       3  27.0
# 9         1       2  14.0

# %% [markdown]
# ## row 선택하기
#   - Series의 경우 []로 row 선택이 가능하나, **DataFrame의 경우는 기본적으로 column을 선택하도록 설계**
#   - **.loc[], .iloc[]**로 row 선택 가능
#     - loc - 인덱스 자체를 사용
#     - iloc - 0 based index로 사용
#     - 이 두 함수는 ,를 사용하여 column 선택도 가능

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.index = np.arange(891) + 100
df
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
# ..           ...       ...     ...
# 986          887         0       2
# 987          888         1       1
# 988          889         0       3
# 989          890         1       1
# 990          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 986                              Montvila, Rev. Juozas    male  27.0      0
# 987                       Graham, Miss. Margaret Edith  female  19.0      0
# 988           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 989                              Behr, Mr. Karl Howell    male  26.0      0
# 990                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 986      0            211536  13.0000   NaN        S
# 987      0            112053  30.0000   B42        S
# 988      2        W./C. 6607  23.4500   NaN        S
# 989      0            111369  30.0000  C148        C
# 990      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# #### loc[index]

# %%
# loc[index 이름] 를 이용하여  row 하나 선택
df.loc[100] # 결과값은 Series 로 반환
# columns 와 index 둘다 있으면 DataFrame
# index 만 있으면 Series
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 100, dtype: object

# %%
# 복수개의 row 선택
df.loc[[100,101,102]]  # 결과값은 DataFrame 으로 반환
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.loc[np.arange(100,105)]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S

# %%
# 100번째 컬럼의 위치값 부터 104번째 컬럼의 위치값까지의 전체 column 을 출력
df[100:105]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex  \
# 200          101         0       3           Petranec, Miss. Matilda  female
# 201          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male
# 202          103         0       1         White, Mr. Richard Frasar    male
# 203          104         0       3        Johansson, Mr. Gustaf Joel    male
# 204          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 200  28.0      0      0   349245   7.8958   NaN        S
# 201   NaN      0      0   349215   7.8958   NaN        S
# 202  21.0      0      1    35281  77.2875   D26        S
# 203  33.0      0      0     7540   8.6542   NaN        S
# 204  37.0      2      0  3101276   7.9250   NaN        S

# %% [markdown]
# ##### iloc[0-base index]

# %%
df.iloc[0] # 결과값은 Series 로 반환된다.
# index 이름은 100 이다.
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Age                               22.0
# SibSp                                1
# Parch                                0
# Ticket                       A/5 21171
# Fare                              7.25
# Cabin                              NaN
# Embarked                             S
# Name: 100, dtype: object

# %%
df.iloc[[0]] # 결과값은 DataFrame 으로 반환
# Out:
#      PassengerId  Survived  Pclass                     Name   Sex   Age  \
# 100            1         0       3  Braund, Mr. Owen Harris  male  22.0
#
#      SibSp  Parch     Ticket  Fare Cabin Embarked
# 100      1      0  A/5 21171  7.25   NaN        S

# %%
df.iloc[np.arange(0,5)]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S

# %%
df.iloc[[0, 100, 200, 4, 7]]
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 100            1         0       3         Braund, Mr. Owen Harris    male
# 200          101         0       3         Petranec, Miss. Matilda  female
# 300          201         0       3  Vande Walle, Mr. Nestor Cyriel    male
# 104            5         0       3        Allen, Mr. William Henry    male
# 107            8         0       3  Palsson, Master. Gosta Leonard    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 100  22.0      1      0  A/5 21171   7.2500   NaN        S
# 200  28.0      0      0     349245   7.8958   NaN        S
# 300  28.0      0      0     345770   9.5000   NaN        S
# 104  35.0      0      0     373450   8.0500   NaN        S
# 107   2.0      3      1     349909  21.0750   NaN        S

# %%
# 0번째 index ~ 4번째 index 위치까지의 데이터
df.iloc[:5]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S

# %%
# 0 ~ 4 번째의 columns 위치의 모든 데이터
df[:5]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S

# %% [markdown]
# ## row, column 동시에 선택하기
# loc[], iloc[] 속성을 이용할때, 콤마를 이용하여 둘다 명시 가능

# %%
# loc 은 index명과 column 명을 이용하여 선택한다.
df.loc[100, 'Pclass']
# Out:
# 3

# %% [markdown]
# ##### iloc 사용하면 row 뿐 아니라 column 도 0-base 로 접근해야 한다

# %%
# iloc 은 위치 기반이기 때문에 명칭이 아닌 위치값을 선택 한다.
# 그래서 iloc[위치, column 명] 은 에러가 발생한다.
df.iloc[0, 'Survived']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:940, in _LocationIndexer._validate_tuple_indexer(self, key)
#     939 try:
# --> 940     self._validate_key(k, i)
#     941 except ValueError as err:
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1576, in _iLocIndexer._validate_key(self, key, axis)
#    1575 else:
# -> 1576     raise ValueError(f"Can only index by location with a [{self._valid_types}]")
#
# ValueError: Can only index by location with a [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array]
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 df.iloc[0, 'Survived']
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1652, in _iLocIndexer._getitem_tuple(self, tup)
#    1651 def _getitem_tuple(self, tup: tuple):
# -> 1652     tup = self._validate_tuple_indexer(tup)
#    1653     with suppress(IndexingError):
#    1654         return self._getitem_lowerdim(tup)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:942, in _LocationIndexer._validate_tuple_indexer(self, key)
#     940         self._validate_key(k, i)
#     941     except ValueError as err:
# --> 942         raise ValueError(
#     943             "Location based indexing can only have "
#     944             f"[{self._valid_types}] types"
#     945         ) from err
#     946 return key
#
# ValueError: Location based indexing can only have [integer, integer slice (START point is INCLUDED, END point is EXCLUDED), listlike of integers, boolean array] types

# %%
df.iloc[0, 1]
# Out:
# 0

# %%
df.head()
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
# 103            4         1       1
# 104            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
# 103       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 104                           Allen, Mr. William Henry    male  35.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S
# 103      0            113803  53.1000  C123        S
# 104      0            373450   8.0500   NaN        S

# %%
df.loc[104, 'Name']
# Out:
# 'Allen, Mr. William Henry'

# %%
df.iloc[4, 3]
# Out:
# 'Allen, Mr. William Henry'

# %%
# 복수 개의 row와 column 을 가져오는 방법
df.loc[[100,102,104], ['Pclass', 'Survived', 'Age']]
# Out:
#      Pclass  Survived   Age
# 100       3         0  22.0
# 102       3         1  26.0
# 104       3         0  35.0

# %%
df.iloc[[0,5,8], [2,4,6]]
# Out:
#      Pclass     Sex  SibSp
# 100       3    male      1
# 105       3    male      0
# 108       3  female      0

# %%
df[['Pclass', 'Survived', 'Age']].loc[[100, 400, 200]]
# Out:
#      Pclass  Survived   Age
# 100       3         0  22.0
# 400       3         1   NaN
# 200       3         0  28.0

# %%
# iloc 을 통해서 column 을 가져오는 것이 아니기 때문에 이것도 가능하다.
df[['Pclass', 'Survived', 'Age']].iloc[np.arange(1,5)]
# Out:
#      Pclass  Survived   Age
# 101       1         1  38.0
# 102       3         1  26.0
# 103       1         1  35.0
# 104       3         0  35.0

# %% [markdown]
# - DataFrame의 값을 가져오는 것이 어떤 함수인지에 따라서 사용 방법도 달라질 수 있다.

# %%
# loc 은 index 명과 column 명으로 호출 하기 때문에 에러 
df.loc[[100,200,300], [0, 1, 3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.loc[[100,200,300], [0, 1, 3]]
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1147, in _LocationIndexer.__getitem__(self, key)
#    1145     if self._is_scalar_access(key):
#    1146         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1147     return self._getitem_tuple(key)
#    1148 else:
#    1149     # we by definition only have the 0th axis
#    1150     axis = self.axis or 0
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1337, in _LocIndexer._getitem_tuple(self, tup)
#    1335 # ugly hack for GH #836
#    1336 if self._multi_take_opportunity(tup):
# -> 1337     return self._multi_take(tup)
#    1339 return self._getitem_tuple_same_dim(tup)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1289, in _LocIndexer._multi_take(self, tup)
#    1272 """
#    1273 Create the indexers for the passed tuple of keys, and
#    1274 executes the take operation. This allows the take operation to be
#    (...)
#    1285 values: same type as the object being indexed
#    1286 """
#    1287 # GH 836
#    1288 d = {
# -> 1289     axis: self._get_listlike_indexer(key, axis)
#    1290     for (key, axis) in zip(tup, self.obj._AXIS_ORDERS)
#    1291 }
#    1292 return self.obj._reindex_with_indexers(d, copy=True, allow_dups=True)
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexing.py:1520, in _LocIndexer._get_listlike_indexer(self, key, axis)
#    1517 ax = self.obj._get_axis(axis)
#    1518 axis_name = self.obj._get_axis_name(axis)
# -> 1520 keyarr, indexer = ax._get_indexer_strict(key, axis_name)
#    1522 return keyarr, indexer
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexes\base.py:6114, in Index._get_indexer_strict(self, key, axis_name)
#    6111 else:
#    6112     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6114 self._raise_if_missing(keyarr, indexer, axis_name)
#    6116 keyarr = self.take(indexer)
#    6117 if isinstance(key, Index):
#    6118     # GH 42790 - Preserve name from an Index
#
# File c:\Program Files\Python312\Lib\site-packages\pandas\core\indexes\base.py:6175, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6173     if use_interval_msg:
#    6174         key = list(key)
# -> 6175     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6177 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6178 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index([0, 1, 3], dtype='int32')] are in the [columns]"

# %%
df[:10].loc[[100,101,102]]
# Out:
#      PassengerId  Survived  Pclass  \
# 100            1         0       3
# 101            2         1       1
# 102            3         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 100                            Braund, Mr. Owen Harris    male  22.0      1
# 101  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 102                             Heikkinen, Miss. Laina  female  26.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 100      0         A/5 21171   7.2500   NaN        S
# 101      0          PC 17599  71.2833   C85        C
# 102      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ##### 특정값 하나 뽑기

# %%
# 이 방식을 제일 추천
df.loc[102, 'Name']
# Out:
# 'Heikkinen, Miss. Laina'

# %%
df['Name'][102]
# Out:
# 'Heikkinen, Miss. Laina'

# %%
df.Name[102]
# Out:
# 'Heikkinen, Miss. Laina'

# %%
import pandas as pd
data = { 'country': [ 'Belgium', 'France', 'Germany', 'Netherlands', 'United Kingdom'],
		'population' : [11.3,64.3, 81.3, 16.9, 64.9],
		'area' : [30510, 671308, 357050, 41526, 244820],
		'capital' : ['Brusseis', 'Paris', 'Berlin', 'Amsterdam' , 'London'] }
	
countries = pd.DataFrame(data)
countries = countries.set_index('country')

countries
# Out:
#                 population    area    capital
# country
# Belgium               11.3   30510   Brusseis
# France                64.3  671308      Paris
# Germany               81.3  357050     Berlin
# Netherlands           16.9   41526  Amsterdam
# United Kingdom        64.9  244820     London

# %% [markdown]
# > 문제1. 각 국가의 수도 인구를 출력하세요

# %%
countries['population']
# Out:
# country
# Belgium           11.3
# France            64.3
# Germany           81.3
# Netherlands       16.9
# United Kingdom    64.9
# Name: population, dtype: float64

# %% [markdown]
# > 문제2. 벨기에 수도 인구를 출력 하세요

# %%
countries.loc['Belgium', 'population']
# Out:
# 11.3

# %%
countries.loc['Belgium']['population']
# Out:
# 11.3

# %%
countries.iloc[0, 0]
# Out:
# 11.3

# %%
countries['population'].loc['Belgium']
# Out:
# 11.3

# %%
countries['population'].iloc[0]
# Out:
# 11.3

# %%
countries.population[0]
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_15284\3628043680.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   countries.population[0]
# 11.3

# %%
countries.population['Belgium']
# Out:
# 11.3

# %% [markdown]
# > 문제3. 벨기에 수도 인구 대비 다른 국가는 몇배 인지 출력하세요

# %%
countries['population'] / countries.loc['Belgium', 'population']
# Out:
# country
# Belgium           1.000000
# France            5.690265
# Germany           7.194690
# Netherlands       1.495575
# United Kingdom    5.743363
# Name: population, dtype: float64

# %%
countries.loc[:, 'population']  / countries.loc['Belgium', 'population']
# Out:
# country
# Belgium           1.000000
# France            5.690265
# Germany           7.194690
# Netherlands       1.495575
# United Kingdom    5.743363
# Name: population, dtype: float64

# %%
countries.iloc[:, 0] / countries.iloc[0,0]
# Out:
# country
# Belgium           1.000000
# France            5.690265
# Germany           7.194690
# Netherlands       1.495575
# United Kingdom    5.743363
# Name: population, dtype: float64
