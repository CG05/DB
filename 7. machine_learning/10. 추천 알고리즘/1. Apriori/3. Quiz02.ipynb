# %% [markdown]
# #Quiz2
# ## 1. 라이브러리 등록

# %% [markdown]
# ##2. 메소드 정의

# %% [markdown]
# ##3. 데이터 입력

# %% [markdown]
# ##4. 지지도 구하기

# %% [markdown]
# ##5. 신뢰도 및 향상도 구하기
# > 향상도(lift)는 1.33으로 같으나 신뢰도(confidence)가 1로 가장 높은 "맥주를 사면 기저귀를 산다"가 발생할 확률이 높은 것을 예측할 수 있다.
