# %%
file = open('Apriori_Dataset1.txt', 'r', encoding='utf-8')

dataset=[]
while True:
  line = file.readline()
  if not line:
    break
  dataset.append(line[2:].split())
dataset
# Out:
# [['Items'],
#  ['달걀,', '라면,', '참치캔'],
#  ['라면,', '햇반'],
#  ['라면,', '콜라'],
#  ['달걀,', '라면,', '햇반'],
#  ['달걀,', '콜라'],
#  ['라면,', '콜라'],
#  ['라면,', '햇반'],
#  ['달걀,', '라면,', '콜라,', '참치캔'],
#  ['달걀,', '라면,', '콜라'],
#  ['양파']]
