# %% [markdown]
# #1. 데이터 읽기

# %% [markdown]
# ##1.1 데이터 읽기

# %% [markdown]
# ##1.2 Quiz

# %% [markdown]
# > 모델을 만들 data와 label을 dataframe으로 만들 것이다. data는 cancer의 data를 label은 target을 이용하여 dataframe을 생성하시오

# %% [markdown]
# #2. 데이터 전처리

# %% [markdown]
# > head를 이용하여 각 feature별로 어떻한 데이터가 어떻게 나타나는지 확인

# %% [markdown]
# > 수치 데이터에 대한 이상치 확인

# %% [markdown]
# > 결과에 대한 분포 확인

# %% [markdown]
# > 간단하게 mean radius를 X축으로 mean texture를 Y 축으로 지정하고 데이터를 분포를 확인했더니 선형 분류를 하게 되면 암의 진단을 분류할 수 있을 것으로 판단된다.

# %% [markdown]
# #3. SVM 선형 분리 모델 만들기

# %% [markdown]
# ##3.1 모델 클래스 로드

# %% [markdown]
# ##3.2 데이터 분리(Quiz)

# %% [markdown]
# > 학습 데이터와 검증 데이터를 7:3 비율로 생성하시오

# %% [markdown]
# ##3.3 모델 생성 및 정확도(Quiz)

# %% [markdown]
# > 모델을 학습시키고 검증데이터로 정확도를 확인하시오

# %% [markdown]
# #4. scaling

# %% [markdown]
# ##4.1 표준화(Quiz)

# %% [markdown]
# > 위의 데이터를 이용하여 표준화 후 모델을 만들고 성능평가를 진행하시오

# %% [markdown]
# ##4.2 정규화(Quiz)

# %% [markdown]
# > 위의 데이터를 이용하여 정규화 후 모델을 만들고 성능평가를 진행하시오

# %% [markdown]
# #5. 교차검증(Quiz)

# %% [markdown]
# > scaling에서 표준화 정보가 더 좋게 나타났다. 표준화에서 사용된 standrad_scaled를 이용하여 교차검증을 구현하시오

# %% [markdown]
# > cross_val_score 함수를 이용하여 간단하게 교차 검증을 진행하였다. 기존 모델인 SVM에 표준화 데이터인 standrad_scaled를 적용하여 조금더 성능이 향상된 모델을 만들 수 있다는 것을 확인했다.

# %% [markdown]
# > cross_validate 함수는 성능 평가 점수 뿐 아니라 학습 시간, 평가 시간을 더 얻을 수 있다.
#
# > 평균 점수 확인 결과 이전보다 높은 성능 평가가 나왔음으로 하이퍼 파라미터를 통해 더 좋은 성능의 모델을 만들어 보자.

# %% [markdown]
# #6. 하이퍼 파라미터(Quiz)

# %% [markdown]
# > 위의 결과를 기반으로 하이퍼 파라미터를 구해 보자. 현재 사용되는 kernel은 linear임으로 cost인 'C'를 이용해서 값은 얻으면 된다. C의 범위는 다음과 같이 적용시킨다.
# - [0.001, 0.01, 0.1, 1, 10, 25, 50, 100]

# %% [markdown]
# #7. 최적의 파라미터를 통한 결과 확인
