# %% [markdown]
# #1. 파일 읽기

# %% [markdown]
# #2. 모델 만들기

# %% [markdown]
# #3. 튜닝

# %% [markdown]
# > 5분 소요

# %% [markdown]
# > 13분정도 걸림

# %% [markdown]
# >4분 소요

# %% [markdown]
# >3분 소요

# %% [markdown]
# > 3분 소요
