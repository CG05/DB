# %% [markdown]
# #1. 데이터 읽어 오기

# %% [markdown]
# #2. 데이터 전처리

# %% [markdown]
# ##2.1 데이터 확인

# %% [markdown]
# ##2.2 데이터 분류

# %% [markdown]
# ##2.3 데이터 벡터화

# %% [markdown]
# #3. 모델 생성

# %% [markdown]
# ##3.1 모델 만들기

# %% [markdown]
# ##3.2 예측

# %% [markdown]
# #4. TF-IDF 기반 모델 생성(Quiz)

# %% [markdown]
# ##4.1 벡터화

# %% [markdown]
# ##4.2 모델 만들기

# %% [markdown]
# ##4.3 예측

# %% [markdown]
# #5. 전처리 후 모델 생성

# %% [markdown]
# ##5.1 데이터 벡터화

# %% [markdown]
# ##5.2 모델 만들기

# %% [markdown]
# #6. 하이퍼 파라미터

# %% [markdown]
# ##6.1 하이퍼 파라미터 적용

# %% [markdown]
# ##6.2 예측

# %% [markdown]
# #7. 파이프라인(Pipeline)

# %% [markdown]
# > 지금까지의 작업 내용을 간략하게 정리하면 다음과 같다.
# 1. 데이터 전처리
# 2. 모델 생성
# 3. 예측
#
# > 이러한 일련의 과정들을 하나의 파이프에서 물이 흘러가듯 표현하는 방식이 파이프라인이다.

# %% [markdown]
# ##7.1 기본 파이프 라인

# %% [markdown]
# ##7.2 하이퍼파라미터 추가
