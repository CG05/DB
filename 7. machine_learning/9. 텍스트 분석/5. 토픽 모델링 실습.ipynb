# %% [markdown]
# #1. 토필 모델링 이해하기

# %% [markdown]
# > 토픽 모델링이란 많은 양의 문서에서 각 문서별 핵심 키워드를 찾아주는 기법이다.

# %% [markdown]
# #2. 데이터 읽어 오기

# %% [markdown]
# #3. 데이터 벡터화

# %% [markdown]
# #4. 모델 생성

# %% [markdown]
# #5. 결과 확인

# %% [markdown]
# > 0번은 그래픽 관련 내용임을 명확히 알 수 있지만 6번은 어떠한 내용을 의미하는지 알 수 없다.
