# %% [markdown]
# #1. 이미지 읽기

# %% [markdown]
# ##1.1. 이미지 정보 확인

# %% [markdown]
# > cv2 패키지 설치
# ```
# pip install opencv-python
# ```

# %% [markdown]
# ##1.2 이미지 읽기

# %% [markdown]
# > imshow함수는 jupyter에서 사용가능하나 colab에서는 사용할 수 없다. 따라서 아래와 같이 코드를 수정해야 한다.

# %% [markdown]
# #2. 동영상 불러오기

# %% [markdown]
# ##2.1 동영상 정보 확인

# %% [markdown]
# ##2.2 동영상 동작시키기

# %% [markdown]
# > GPU를 이용했지만 큰 차이는 없으며 생각보다 많이 느리다.

# %% [markdown]
# #3. 동영상을 이미지로 저장하기
