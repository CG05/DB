# %% [markdown]
# # 파일 이동
# > 파일 업로드 시 30분 정도 소요 됨으로 수업 진행 전달 데이터 전달

# %% [markdown]
# # 1. 데이터 확인

# %%
import os 

base_path = 'image/cats_and_dogs/data'
data_list = ['test', 'train', 'validation']
animal_list = ['cats', 'dogs']

for data_title in data_list:
    for animal in animal_list:
        print(data_title, ' ', animal, ' 이미지 전체 개수 : ', 
            len(os.listdir(base_path+"/"+data_title+"/"+animal)))
# Out:
# test   cats  이미지 전체 개수 :  500
# test   dogs  이미지 전체 개수 :  500
# train   cats  이미지 전체 개수 :  941
# train   dogs  이미지 전체 개수 :  274
# validation   cats  이미지 전체 개수 :  450
# validation   dogs  이미지 전체 개수 :  420

# %% [markdown]
# 복사가 잘 되었는지 확인하기 위해 각 분할(훈련/검증/테스트)에 들어 있는 사진의 개수를 카운트해 보죠:

# %% [markdown]
# 이제 2,000개의 훈련 이미지, 1,000개의 검증 이미지, 1,000개의 테스트 이미지가 준비되었다.

# %% [markdown]
# # 2. 모델 구성하기

# %%
from keras import layers, Input, models 

model = models.Sequential()
model.add(Input(shape=(150, 150, 3)))
model.add(layers.Conv2D(32, (3,3), activation='relu'))
model.add(layers.MaxPool2D((2,2)))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 896 (3.50 KB)
#  Trainable params: 896 (3.50 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPool2D((2,2)))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 19,392 (75.75 KB)
#  Trainable params: 19,392 (75.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPool2D((2,2)))

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 93,248 (364.25 KB)
#  Trainable params: 93,248 (364.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.add(layers.Conv2D(128, (3,3), activation='relu'))
model.add(layers.MaxPool2D((2,2)))

# %%
model.add(layers.Flatten())
model.add(layers.Dense(512, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %% [markdown]
# > 개와 고양이 중 하나를 선택할 것이기 때문에 sigmoid를 최종으로 사용한다.
#
# https://opentutorials.org/module/5268/29787

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 148, 148, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 72, 72, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 36, 36, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 34, 34, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 17, 17, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 15, 15, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 7, 7, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 6272)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │     3,211,776 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,453,121 (13.17 MB)
#  Trainable params: 3,453,121 (13.17 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 컴파일 단계에서 이전과 같이 `RMSprop` 옵티마이저를 선택하겠습니다. 네트워크의 마지막이 하나의 시그모이드 유닛이기 때문에 이진 크로스엔트로피(binary crossentropy)를 손실로 사용합니다(4장 5절에서 다양한 경우에 사용할 수 있는 손실 함수 목록을 볼 수 있습니다).

# %%
from keras import optimizers

model.compile(loss='binary_crossentropy', optimizer=optimizers.RMSprop(learning_rate=0.0001),
              metrics=['accuracy'])

# %% [markdown]
# # 3. 데이터 전처리
#
# > 데이터는 네트워크에 주입되기 전에 부동 소수 타입의 텐서로 적절하게 전처리되어 있어야 한다. 현재 데이터는 JPEG 파일로 되어 있으므로 정수 타입의 데이터를 가지고 있다. 이미지를 네트워크에 주입하려면 다음 과정을 따라야 한다.
# 1.	사진 파일을 읽는다.
# 2.	이미지 콘텐츠를 RGB 픽셀 값으로 디코딩한다.
# 3.	디코딩한 결과를 부동 소수 타입의 텐서로 변환한다.
#
# > 위의 복잡한 기능을 한번에 처리해 주는 것이 `ImageDataGenerator` 클래스이다.

# %% [markdown]
# ## 3.1 부동 소수 타입의 텐서 변환

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
test_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# ## 3.2 generator 만들기

# %%
train_dir = base_path + "/train"

train_datagen = train_datagen.flow_from_directory (
    train_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 1215 images belonging to 2 classes.

# %% [markdown]
# > class_mode는 분류 방식에 대해서 지정한다.
# - categorical : 2D one-hot 부호화된 라벨이 반환됨
# - binary : 1D 이진 라벨이 반환됨
# - sparse : 1D 정수 라벨이 반환됨
# - None : 라벨이 반환되지 않음

# %%
validation_dir = base_path + "/validation"

validation_gen = test_datagen.flow_from_directory(
    validation_dir,
    target_size=(150, 150),
    batch_size=20,
    class_mode='binary'
)
# Out:
# Found 870 images belonging to 2 classes.

# %% [markdown]
# # 4. 모델 만들기

# %% [markdown]
# ## 4.1 에코스텝 구하기

# %%
train_datagen

# %%
data_batch, labels_batch = train_datagen[0]
print('배치 데이터 크기 :', data_batch.shape)
print('배치 레이블 크기 :', labels_batch.shape)
# Out:
# 배치 데이터 크기 : (20, 150, 150, 3)
# 배치 레이블 크기 : (20,)

# %% [markdown]
# > generator에는 data와 label 정보가 저장되어 있다. 3.2에서 generator 생성 시 이미지 사이트는 150 x 150으로 설정했고 batch size는 20으로 설정했다.
#
# > 위 코드 실행 결과 20개의 데이터 (150, 150, 3)(가로, 세로, 색상)와 20개의 결과 정보가 있는 것을 확인할 수 있다. 훈련데이터의 경우 고양이 1000개 강아지 1000개 총 2000개의 데이터를 사용하고 있음으로 100번을 반복해야 모든 데이터를 학습시킬 수 있다.

# %% [markdown]
# ## 4.2 모델 만들기

# %%
history = model.fit(
    train_datagen, epochs=30, validation_data=validation_gen
)
# Out:
# Epoch 1/30
# C:\Users\kys05\AppData\Roaming\Python\Python312\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 301ms/step - accuracy: 0.7882 - loss: 0.5487 - val_accuracy: 0.5172 - val_loss: 0.8118
# Epoch 2/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 285ms/step - accuracy: 0.7611 - loss: 0.5585 - val_accuracy: 0.5172 - val_loss: 0.8234
# Epoch 3/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 290ms/step - accuracy: 0.7853 - loss: 0.5191 - val_accuracy: 0.5172 - val_loss: 0.8297
# Epoch 4/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 286ms/step - accuracy: 0.7736 - loss: 0.5314 - val_accuracy: 0.5172 - val_loss: 0.9836
# Epoch 5/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 17s 283ms/step - accuracy: 0.7509 - loss: 0.5525 - val_accuracy: 0.5172 - val_loss: 0.8575
# Epoch 6/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 18s 291ms/step - accuracy: 0.7803 - loss: 0.5132 - val_accuracy: 0.5333 - val_loss: 0.8251
# Epoch 7/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 314ms/step - accuracy: 0.8004 - loss: 0.4793 - val_accuracy: 0.5517 - val_loss: 0.7643
# Epoch 8/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 324ms/step - accuracy: 0.7953 - loss: 0.4927 - val_accuracy: 0.5448 - val_loss: 0.8805
# Epoch 9/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 327ms/step - accuracy: 0.7893 - loss: 0.4647 - val_accuracy: 0.6000 - val_loss: 0.6977
# Epoch 10/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 308ms/step - accuracy: 0.8138 - loss: 0.4352 - val_accuracy: 0.5506 - val_loss: 1.0375
# Epoch 11/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.8366 - loss: 0.4051 - val_accuracy: 0.6000 - val_loss: 0.7686
# Epoch 12/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 309ms/step - accuracy: 0.8538 - loss: 0.3578 - val_accuracy: 0.5862 - val_loss: 0.9096
# Epoch 13/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - accuracy: 0.8367 - loss: 0.3849 - val_accuracy: 0.6483 - val_loss: 0.6707
# Epoch 14/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 315ms/step - accuracy: 0.8235 - loss: 0.3880 - val_accuracy: 0.6241 - val_loss: 0.7520
# Epoch 15/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 309ms/step - accuracy: 0.8663 - loss: 0.3474 - val_accuracy: 0.6460 - val_loss: 0.7520
# Epoch 16/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 316ms/step - accuracy: 0.8444 - loss: 0.3526 - val_accuracy: 0.6057 - val_loss: 0.9042
# Epoch 17/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 0.8623 - loss: 0.3206 - val_accuracy: 0.6736 - val_loss: 0.6139
# Epoch 18/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 306ms/step - accuracy: 0.8760 - loss: 0.2897 - val_accuracy: 0.6609 - val_loss: 0.7350
# Epoch 19/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 307ms/step - accuracy: 0.8796 - loss: 0.3046 - val_accuracy: 0.6299 - val_loss: 0.9391
# Epoch 20/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 0.8809 - loss: 0.2783 - val_accuracy: 0.6977 - val_loss: 0.6714
# Epoch 21/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.8854 - loss: 0.2747 - val_accuracy: 0.6713 - val_loss: 0.8195
# Epoch 22/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 306ms/step - accuracy: 0.9006 - loss: 0.2365 - val_accuracy: 0.6345 - val_loss: 0.9814
# Epoch 23/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 313ms/step - accuracy: 0.9210 - loss: 0.2048 - val_accuracy: 0.6770 - val_loss: 0.7637
# Epoch 24/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 20s 321ms/step - accuracy: 0.9131 - loss: 0.2273 - val_accuracy: 0.6368 - val_loss: 1.0539
# Epoch 25/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 313ms/step - accuracy: 0.9266 - loss: 0.1953 - val_accuracy: 0.6080 - val_loss: 1.3740
# Epoch 26/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 0.9282 - loss: 0.1865 - val_accuracy: 0.6805 - val_loss: 0.8810
# Epoch 27/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 307ms/step - accuracy: 0.9409 - loss: 0.1719 - val_accuracy: 0.6644 - val_loss: 0.9736
# Epoch 28/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 310ms/step - accuracy: 0.9339 - loss: 0.1538 - val_accuracy: 0.6563 - val_loss: 1.1106
# Epoch 29/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.9523 - loss: 0.1438 - val_accuracy: 0.6391 - val_loss: 1.3301
# Epoch 30/30
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 19s 311ms/step - accuracy: 0.9610 - loss: 0.1232 - val_accuracy: 0.6575 - val_loss: 1.1663

# %% [markdown]
# > 대략 15분 정도 소요됨

# %% [markdown]
# # 5. 백업

# %% [markdown]
# ## 5.1 모델 저장

# %%
model.save('model/cats_and_dogs_0718.keras')

# %% [markdown]
# ## 5.2 히스토리 저장

# %%
import numpy as np

np.save('model/my_history_0718.npy', history.history)
