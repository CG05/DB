# %% [markdown]
# # 위 데이터를 이용하여 인원을 예측하고 시각화 해보기

# %% [markdown]
# ## 결측치 처리

# %% [markdown]
# ## 시계열 데이터 준비

# %% [markdown]
# ## 데이터 정규화

# %% [markdown]
# ## 데이터 분할

# %% [markdown]
# ## 시계열 데이터 생성 함수

# %% [markdown]
# ## 시계열 데이터 생성

# %% [markdown]
# ## SimpleRNN 모델 구성

# %% [markdown]
# ## 모델 훈련

# %% [markdown]
# ## 모델 평가

# %% [markdown]
# ## 결과 시각화

# %% [markdown]
# ## 원 데이터로 시각화
