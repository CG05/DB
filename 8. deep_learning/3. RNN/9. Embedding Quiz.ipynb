# %% [markdown]
# # 위 데이터를 이용하여 감성 분석을 해 보세요
# - train_labels 의 내용은 0은 부정, 1은 긍정이다

# %% [markdown]
# ## Tokenizer 를 num_word=10000, oov_token="<OOV>" 으로 설정한다.
# ```
# tokenizer = Tokenizer(num_words=10000, oov_token="<OOV>")
# train_X = pad_sequences(train_X, padding='post', maxlen=120)
# ```

# %% [markdown]
# ## 테스트 데이터 전처리

# %% [markdown]
# ## 모델 구성
# ```
# model = Sequential([
#     Embedding(10000, 64, input_length=120),
#     Bidirectional(LSTM(64)),
#     Dense(64, activation='relu'),
#     Dropout(0.5),
#     Dense(1, activation='sigmoid')
# ])
# ```

# %% [markdown]
# ## 모델 compile
# - optimizer='adam' 으로 loss='binary_crossentropy', metrics 는 'accuracy' 로 설정한다.

# %% [markdown]
# ## 모델 훈련
# - 시간이 많이 걸리기 때문에 epochs 는 10으로 설정한다.

# %% [markdown]
# ## 시각화
